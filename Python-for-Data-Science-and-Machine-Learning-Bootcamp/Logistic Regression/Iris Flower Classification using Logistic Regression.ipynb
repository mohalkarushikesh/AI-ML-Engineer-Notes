# %% [markdown]
# # Iris Flower Classification using Logistic Regression
#
# This project demonstrates the use of logistic regression for multi-class classification on the classic Iris dataset. It includes data exploration, model training, prediction, and visualization of results.
#
# ## 🔍 Project Overview
#
# - **Dataset**: Iris dataset (from `sklearn.datasets`)
# - **Goal**: Classify iris flowers into three species (*setosa*, *versicolor*, *virginica*) based on their sepal and petal measurements
# - **Model Used**: Logistic Regression (`multi_class='ovr'`)
#
# ## 📈 Workflow
#
# 1. **Data Loading and Exploration**
#    - Loaded using `load_iris()`
#    - Basic data analysis with `.info()`, `.describe()`, and `pairplot`
#
# 2. **Model Building**
#    - Split data into training and test sets (80/20)
#    - Trained a logistic regression model
#
# 3. **Evaluation**
#    - Calculated accuracy score
#    - Visualized actual vs. predicted labels using bar and line plots
#
# ## 📦 Technologies Used
#
# - Python
# - Pandas, NumPy
# - Matplotlib, Seaborn
# - scikit-learn
#
# ## ▶️ How to Run
#
# 1. Ensure dependencies are installed:
#    ```bash
#    pip install pandas numpy matplotlib seaborn scikit-learn
#    ```
# 2. Run the script in any Python environment or Jupyter Notebook
#
# ## 📌 Sample Output
#
# - Accuracy score printed to console
# - Plots comparing actual vs. predicted species labels

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 
import seaborn as sns
# dataset
from sklearn.datasets import load_iris
# model selection 
from sklearn.model_selection import train_test_split
# model 
from sklearn.linear_model import LogisticRegression
# metrics 
from sklearn.metrics import accuracy_score

# %%
# load the iris data
iris = load_iris()
x, y = iris.data, iris.target

# %%
df = pd.DataFrame(iris.data)
df.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       150 non-null    float64
#  1   1       150 non-null    float64
#  2   2       150 non-null    float64
#  3   3       150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df)
plt.show()

# %%
# split the data into tranning and testing set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# create logitics regression model
model = LogisticRegression(multi_class='ovr', max_iter=1000)
model.fit(x_train, y_train)
# Out:
# c:\Users\2327238\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='ovr')

# %%
# predictions
y_predict = model.predict(x_test)

# %%
# Evaluation                                            
accuracy = accuracy_score(y_test, y_predict)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9666666666666667

# %%
comparison = pd.DataFrame({'Actual': y_test, 'Predicted':y_predict})
print(comparison)
# Out:
#     Actual  Predicted
# 0        1          1
# 1        0          0
# 2        2          2
# 3        1          1
# 4        1          1
# 5        0          0
# 6        1          1
# 7        2          2
# 8        1          1
# 9        1          1
# 10       2          2
# 11       0          0
# 12       0          0
# 13       0          0
# 14       0          0
# 15       1          2
# 16       2          2
# 17       1          1
# 18       1          1
# 19       2          2
# 20       0          0
# 21       2          2
# 22       0          0
# 23       2          2
# 24       2          2
# 25       2          2
# 26       2          2
# 27       2          2
# 28       0          0
# 29       0          0

# %%
indices = np.arange(len(y_test))  # Create indices for x-axis

plt.bar(indices - 0.2, y_test, width=0.4, label='Actual', color='blue', alpha=0.6)
plt.bar(indices + 0.2, y_predict, width=0.4, label='Predicted', color='orange', alpha=0.6)

plt.xlabel('Sample Index')
plt.ylabel('Class Label')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Use indices for the x-axis
indices = range(len(y_test))

# Plot actual values as a red line
plt.plot(indices, y_test, color='red', label='Actual', linestyle='-', marker='o')

# Plot predicted values as a green line
plt.plot(indices, y_predict, color='green', label='Predicted', linestyle='-', marker='x')

# Add title and labels
plt.title("Actual vs Predicted Values")
plt.xlabel("Sample Index")
plt.ylabel("Class Label")
plt.legend()
plt.show()
