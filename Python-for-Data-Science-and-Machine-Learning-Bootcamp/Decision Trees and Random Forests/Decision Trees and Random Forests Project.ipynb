# %% [markdown]
# ### 📌 **Project Title**: Predicting Loan Default Risk Using Decision Trees & Random Forests
#
# **Objective**:
# To build a machine learning classification model that predicts whether a loan applicant is likely to fully repay their loan or default, based on financial and demographic features.
#
# **Tools & Technologies**:
# Python, Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn
#
# **Key Tasks Performed**:
#
# - **Data Exploration & Visualization**:
#   Explored the distribution of FICO scores, credit policies, and loan repayment status through histograms, jointplots, and countplots to uncover risk patterns and correlations.
#
# - **Feature Engineering**:
#   Transformed categorical features using one-hot encoding to prepare the data for modeling. Focused on the loan purpose feature to understand behavioral signals.
#
# - **Model Building**:
#   Implemented both a **Decision Tree Classifier** and a **Random Forest Classifier** to train and evaluate predictions on borrower default likelihood. Compared model performance using accuracy metrics, precision, recall, and F1-scores.
#
# - **Model Evaluation**:
#   Assessed model performance using confusion matrices and classification reports. Random Forest outperformed the standalone Decision Tree in predictive accuracy and generalization.
#
# **Outcome**:
# The model successfully identified patterns in borrower behavior and financial data that correlate with loan repayment outcomes. This type of solution can help financial institutions make data-driven lending decisions and proactively manage credit risk.

# %%
# Import necessary libraries for data handling and visualization
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load the dataset
df = pd.read_csv('loan_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
# Compare FICO scores by credit policy (1 = meets credit policy)
plt.figure(figsize=(10, 6))
df[df['credit.policy'] == 1]['fico'].hist(bins=35, color='blue', label='Credit Policy = 1', alpha=0.6)
df[df['credit.policy'] == 0]['fico'].hist(bins=35, color='red', label = 'Credit Policy = 0', alpha=0.6)
plt.legend()
plt.xlabel('FICO SCORE')
# Out:
# Text(0.5, 0, 'FICO SCORE')

# %%
# Compare FICO scores by loan repayment status
plt.figure(figsize=(10, 6))
df[df['not.fully.paid'] == 1]['fico'].hist(bins=35, color='blue', label='Not Fully Paid = 1', alpha=0.6)
df[df['not.fully.paid'] == 0]['fico'].hist(bins=35, color='red', label = 'Not Fully Paid = 0', alpha=0.6)
plt.legend()
plt.xlabel('FICO SCORE')
# Out:
# Text(0.5, 0, 'FICO SCORE')

# %%
# Visualize loan purposes and their relationship to repayment status
plt.figure(figsize=(15, 7))
sns.countplot(x = 'purpose', hue='not.fully.paid', data=df, palette='Set1')
# Out:
# <Axes: xlabel='purpose', ylabel='count'>

# %%
# Joint distribution of FICO scores and interest rates
sns.jointplot(x = 'fico', y = 'int.rate', data=df, color='purple')

# %%
# Linear model plots conditioned on credit policy and loan repayment
plt.figure(figsize=(11, 7))
sns.lmplot(y='int.rate', x = 'fico', data=df, hue='credit.policy', col='not.fully.paid', palette='Set1')

# %%
# Create list of elements containing the string 'purpose', call it cat_feats
# Prepare categorical feature(s) for modeling by one-hot encoding
cat_feats = ['purpose']

# %%
# Now use pd.get_dummies(df, columns=cat_feats, drop_first=True) to create fixed larger dataframe that has new feature columns 
# with new dummy variables set this dataframe as final_data
final_data = pd.get_dummies(df, columns=cat_feats, drop_first=True)

# %%
# Preview new dataset with dummy variables
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   credit.policy               9578 non-null   int64
#  1   int.rate                    9578 non-null   float64
#  2   installment                 9578 non-null   float64
#  3   log.annual.inc              9578 non-null   float64
#  4   dti                         9578 non-null   float64
#  5   fico                        9578 non-null   int64
#  6   days.with.cr.line           9578 non-null   float64
#  7   revol.bal                   9578 non-null   int64
#  8   revol.util                  9578 non-null   float64
#  9   inq.last.6mths              9578 non-null   int64
#  10  delinq.2yrs                 9578 non-null   int64
#  11  pub.rec                     9578 non-null   int64
#  12  not.fully.paid              9578 non-null   int64
# ...

# %%
# Preview new dataset with dummy variables
final_data.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation  \
# ...

# %%
# Split data into training and testing sets
from sklearn.model_selection import train_test_split

# %%
X = final_data.drop('not.fully.paid', axis=1)
y = final_data['not.fully.paid']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# Tranning Decision Tree Model

# %%
# Import Decision Tree Model
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
# Fit the model 
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Make predictions using the Decision Tree
pred = dtree.predict(X_test)

# %%
# Evaluation of D Tree performance
from sklearn.metrics  import confusion_matrix, classification_report
print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84      2339
#            1       0.23      0.19      0.21       535
#
#     accuracy                           0.73      2874
#    macro avg       0.53      0.52      0.52      2874
# weighted avg       0.71      0.73      0.72      2874

# %%
print(confusion_matrix(pred, y_test))
# Out:
# [[1999  340]
#  [ 432  103]]

# %% [markdown]
# Tranning Random Forests Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Train a Random Forest classifier with 300 trees
rfc = RandomForestClassifier(n_estimators=300)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
# Predictions for Random Forest model
predict = rfc.predict(X_test)

# %%
# Evaluate Random Forest model
print(classification_report(predict, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92      2858
#            1       0.02      0.56      0.04        16
#
#     accuracy                           0.85      2874
#    macro avg       0.51      0.71      0.48      2874
# weighted avg       0.99      0.85      0.91      2874

# %%
print(confusion_matrix(predict, y_test))
# Out:
# [[2424  434]
#  [   7    9]]
