# %% [markdown]
# ```
# TF-IDF : Term frequency - Inverse document frequency
# TF = No of rep of words in sentence / total no of words in senctence
# IDF = loge(no of sentence / no of sentences containing the world)
# TF * IDF
#
# capture word importance
#
# Advantages
#     Intutive
#     Fixed size -> vocab size
#     word importance getting capture
# Dis-Advantages
#     Sparsity still exits
#     OOV

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# Example dataset
corpus = [
    "Free entry in a weekly competition to win tickets",
    "Ok lar... Joking wif u only",
    "U dun say so early hor... U c already then say",
    "Free tickets available now"
]

# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer(stop_words='english')

# Fit and transform the corpus
X = vectorizer.fit_transform(corpus)

# Convert to DataFrame for readability
tfidf_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())

print(tfidf_df)
# Out:
#    available  competition       dun     early     entry      free       hor  \
# 0   0.000000     0.436719  0.000000  0.000000  0.436719  0.344315  0.000000
# 1   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000     0.000000  0.377964  0.377964  0.000000  0.000000  0.377964
# 3   0.667679     0.000000  0.000000  0.000000  0.000000  0.526405  0.000000
#
#    joking  lar   ok       say   tickets    weekly  wif       win
# 0     0.0  0.0  0.0  0.000000  0.344315  0.436719  0.0  0.436719
# 1     0.5  0.5  0.5  0.000000  0.000000  0.000000  0.5  0.000000
# 2     0.0  0.0  0.0  0.755929  0.000000  0.000000  0.0  0.000000
# 3     0.0  0.0  0.0  0.000000  0.526405  0.000000  0.0  0.000000
